# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/dataset-initiale/job_data_cleaned_final.csv

# %%
import pandas as pd
import xgboost as xgb
import joblib
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# === 1. Charger la dataset ===
df = pd.read_csv('/kaggle/input/dataset-initiale/job_data_cleaned_final.csv')
# === 2. Supprimer les colonnes inutiles ===
df = df.drop(columns=['Description', 'Location', 'Date', 'Company', 'URL'])

# === 3. Supprimer les lignes sans salaire ===
df = df.dropna(subset=['Salary'])

# === 4. Supprimer les lignes avec Job Title manquant ===
df = df[df['Job Title'].notnull()]

# %%
df.head()
# Out:
#                 Job Title    Salary  \
# 90          Data Engineer  195000.0
# 101         Data Engineer  125000.0
# 146          Data Analyst  111175.0
# 155        Data Scientist  112500.0
# 220  Senior Data Engineer  325000.0
#
#                                                 Skills
# 90                                                 NaN
# 101                                                NaN
# 146                                        python, sql
# 155                                             python
# 220  aws, bash, docker, hadoop, java, jira, kafka, ...

# %%
# === 5. One-hot encoding pour Job Title ===
job_title_dummies = pd.get_dummies(df['Job Title'], prefix='jobtitle')

# %%
df.head()
# Out:
#                 Job Title    Salary  \
# 90          Data Engineer  195000.0
# 101         Data Engineer  125000.0
# 146          Data Analyst  111175.0
# 155        Data Scientist  112500.0
# 220  Senior Data Engineer  325000.0
#
#                                                 Skills
# 90                                                 NaN
# 101                                                NaN
# 146                                        python, sql
# 155                                             python
# 220  aws, bash, docker, hadoop, java, jira, kafka, ...

# %%
# === 5. Préparer la liste complète des skills ===
all_skills = {
    '', 'airflow', 'airtable', 'alteryx', 'angular', 'angular.js', 'ansible', 'apl', 'arch',
    'asana', 'asp.net', 'asp.net core', 'asp.netcore', 'assembly', 'atlassian', 'aurora', 'aws',
    'azure', 'bash', 'bigquery', 'bitbucket', 'blazor', 'c', 'c#', 'c++', 'capacitor', 'cassandra',
    'centos', 'chainer', 'chef', 'clickup', 'clojure', 'cobol', 'codecommit', 'cognos', 'colocation',
    'confluence', 'cordova', 'couchbase', 'couchdb', 'crystal', 'css', 'dart', 'databricks', 'datarobot',
    'dax', 'db2', 'debian', 'delphi', 'deno', 'digitalocean', 'dingtalk', 'django', 'dlib', 'docker',
    'dplyr', 'drupal', 'dynamodb', 'elasticsearch', 'electron', 'elixir', 'ember.js', 'erlang',
    'esquisse', 'excel', 'express', 'f#', 'fastapi', 'fastify', 'fedora', 'firebase', 'firestore',
    'flask', 'flow', 'flutter', 'fortran', 'gatsby', 'gcp', 'gdpr', 'ggplot2', 'git', 'github',
    'gitlab', 'go', 'golang', 'google chat', 'graphql', 'groovy', 'gtx', 'hadoop', 'haskell',
    'heroku', 'homebrew', 'html', 'hugging face', 'huggingface', 'ibm cloud', 'ionic', 'java',
    'javascript', 'jenkins', 'jira', 'jquery', 'julia', 'jupyter', 'kafka', 'kali', 'keras',
    'kotlin', 'kubernetes', 'laravel', 'linode', 'linux', 'lisp', 'looker', 'lua', 'macos',
    'mariadb', 'matlab', 'matplotlib', 'mattermost', 'microsoft lists', 'microsoft teams',
    'microstrategy', 'mlpack', 'mlr', 'monday.com', 'mongo', 'mongodb', 'ms access', 'msaccess',
    'mxnet', 'mysql', 'neo4j', 'next.js', 'nltk', 'no-sql', 'node', 'node.js', 'nosql', 'notion',
    'npm', 'nuix', 'numpy', 'nuxt.js', 'objective-c', 'ocaml', 'opencv', 'openstack', 'oracle',
    'outlook', 'ovh', 'pandas', 'pascal', 'perl', 'phoenix', 'php', 'planner', 'play framework',
    'plotly', 'postgresql', 'power bi', 'powerbi', 'powerpoint', 'powershell', 'pulumi', 'puppet',
    'pyspark', 'python', 'pytorch', 'qlik', 'qt', 'r', 'react', 'react.js', 'redhat', 'redis',
    'redshift', 'ringcentral', 'rocketchat', 'rshiny', 'ruby', 'ruby on rails', 'rubyon rails',
    'rust', 'sap', 'sas', 'sass', 'scala', 'scikit-learn', 'seaborn', 'selenium', 'sharepoint',
    'sheets', 'shell', 'shogun', 'slack', 'smartsheet', 'snowflake', 'solidity', 'spark', 'splunk',
    'spreadsheet', 'spring'
}
all_skills = {s.strip().lower() for s in all_skills if s.strip()}

# %%
# === 6. One-hot encoding pour Skills (version optimisée) ===
df['Skills'] = df['Skills'].fillna('')

skill_dict = {}
for skill in all_skills:
    skill_dict[f'skill_{skill}'] = df['Skills'].str.contains(fr'\b{skill}\b', case=False, regex=True).astype(int)
skill_features = pd.DataFrame(skill_dict, index=df.index)

# %%
# === 7. Fusionner les features ===
df_final = pd.concat([df, job_title_dummies, skill_features], axis=1)
df_final = df_final.drop(columns=['Job Title', 'Skills'])

# === Afficher la première ligne après one-hot encoding ===
print("Première ligne du dataset après one-hot encoding:")
print(df_final.iloc[0])
# Out:
# Première ligne du dataset après one-hot encoding:
# Salary                       195000.0
# jobtitle_Business Analyst       False
# jobtitle_Cloud Engineer         False
# jobtitle_Data Analyst           False
# jobtitle_Data Engineer           True
#                                ...
# skill_seaborn                       0
# skill_matplotlib                    0
# skill_mysql                         0
# skill_airflow                       0
# skill_fedora                        0
# Name: 90, Length: 214, dtype: object

# %%
# Convertir toutes les colonnes booléennes en 0/1
bool_cols = df_final.select_dtypes(include=['bool']).columns
df_final[bool_cols] = df_final[bool_cols].astype(int)

# %%
print("Première ligne du dataset après one-hot encoding:")
print(df_final.iloc[0])
# Out:
# Première ligne du dataset après one-hot encoding:
# Salary                       195000.0
# jobtitle_Business Analyst         0.0
# jobtitle_Cloud Engineer           0.0
# jobtitle_Data Analyst             0.0
# jobtitle_Data Engineer            1.0
#                                ...
# skill_seaborn                     0.0
# skill_matplotlib                  0.0
# skill_mysql                       0.0
# skill_airflow                     0.0
# skill_fedora                      0.0
# Name: 90, Length: 214, dtype: float64

# %%
# === 8. Normaliser le salaire (Min-Max Scaling) ===
salary_min = df_final['Salary'].min()
salary_max = df_final['Salary'].max()
df_final['Salary_Norm'] = (df_final['Salary'] - salary_min) / (salary_max - salary_min)

# %%
# === 9. Préparer X et y ===
X = df_final.drop(columns=['Salary', 'Salary_Norm'])
y = df_final['Salary_Norm']

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import numpy as np
import xgboost as xgb
import joblib

# Paramètres optimaux trouvés
best_params = {
    'learning_rate': 0.1,
    'max_depth': 9,
    'n_estimators': 100,
    'subsample': 0.7,
    'random_state': 42
}

# Train/test split identique au Deep Learning
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=42)

# Instanciation et entraînement
xgb_model = xgb.XGBRegressor(**best_params)
xgb_model.fit(X_train, y_train)

# Prédictions sur le jeu de validation
y_pred = xgb_model.predict(X_val)

# Évaluation
rmse_xgb = np.sqrt(mean_squared_error(y_val, y_pred))
r2_xgb = r2_score(y_val, y_pred)

print(f"\n✅ XGBoost - Validation RMSE : {rmse_xgb:.2f}")
print(f"✅ XGBoost - Validation R²   : {r2_xgb:.2f}")

# Sauvegarde du modèle
joblib.dump(xgb_model, 'xgb_salary_model.pkl')
# Out:
# ✅ XGBoost - Validation RMSE : 0.04
# ✅ XGBoost - Validation R²   : 0.29
# ['xgb_salary_model.pkl']

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
import joblib

# === 0. Vérification GPU ===
print("TensorFlow version:", tf.__version__)
print("GPU available:", tf.config.list_physical_devices('GPU'))

# === 1. Préparation des données ===
X = df_final.drop(columns=['Salary'])
y = df_final['Salary'].values  # Plus de normalisation ici

# Split identique à XGBoost
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=42)

# Standardisation des features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

# === 2. Modèle Deep Learning ===
model = keras.Sequential([
    layers.Dense(256, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    layers.Dropout(0.3),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)  # Prédiction brute du salaire
])

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss='mean_squared_error',
    metrics=[keras.metrics.RootMeanSquaredError()]
)

# === 3. Callbacks ===
checkpoint_cb = keras.callbacks.ModelCheckpoint(
    'best_model.keras',
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

early_stop = keras.callbacks.EarlyStopping(
    patience=10,
    restore_best_weights=True,
    verbose=1
)

# === 4. Entraînement sur GPU ===
with tf.device('/GPU:0'):
    history = model.fit(
        X_train_scaled, y_train,
        validation_data=(X_val_scaled, y_val),
        epochs=100,
        batch_size=32,
        callbacks=[early_stop, checkpoint_cb],
        verbose=1
    )

# === 5. Évaluation ===
y_pred = model.predict(X_val_scaled).flatten()

rmse_dl = np.sqrt(mean_squared_error(y_val, y_pred))
r2_dl = r2_score(y_val, y_pred)

print(f"\n✅ Deep Learning - Validation RMSE : {rmse_dl:.2f}")
print(f"✅ Deep Learning - Validation R²   : {r2_dl:.2f}")

# === 6. Sauvegarde du modèle et scaler ===
model.save('final_deep_learning_model.h5')
joblib.dump(scaler, 'feature_scaler.pkl')


# === 7. Exemples de prédictions ===
print("\nExemples de salaires DL prédits vs réels :")
for pred, real in zip(y_pred[:5], y_val[:5]):
    print(f"Prévu : {pred:.2f} | Réel : {real:.2f}")
# Out:
# TensorFlow version: 2.18.0
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10983374848.0000 - root_mean_squared_error: 102732.3359
# Epoch 1: val_loss improved from inf to 465300320.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 10974416896.0000 - root_mean_squared_error: 102685.4688 - val_loss: 465300320.0000 - val_root_mean_squared_error: 21570.8203
# Epoch 2/100
# 612/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 542497984.0000 - root_mean_squared_error: 23276.6074
# Epoch 2: val_loss improved from 465300320.00000 to 272091040.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 541791360.0000 - root_mean_squared_error: 23261.2988 - val_loss: 272091040.0000 - val_root_mean_squared_error: 16495.1816
# Epoch 3/100
# 610/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 399977952.0000 - root_mean_squared_error: 19984.4707
# Epoch 3: val_loss improved from 272091040.00000 to 209827200.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 399585664.0000 - root_mean_squared_error: 19974.7891 - val_loss: 209827200.0000 - val_root_mean_squared_error: 14485.4131
# Epoch 4/100
# 609/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 341257536.0000 - root_mean_squared_error: 18467.3574
# Epoch 4: val_loss improved from 209827200.00000 to 184457232.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 340988864.0000 - root_mean_squared_error: 18460.1230 - val_loss: 184457232.0000 - val_root_mean_squared_error: 13581.5039
# Epoch 5/100
# 617/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 310035040.0000 - root_mean_squared_error: 17597.1387
# Epoch 5: val_loss improved from 184457232.00000 to 161449152.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 309983584.0000 - root_mean_squared_error: 17595.7363 - val_loss: 161449152.0000 - val_root_mean_squared_error: 12706.2646
# Epoch 6/100
# 618/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 294881248.0000 - root_mean_squared_error: 17164.7695
# Epoch 6: val_loss improved from 161449152.00000 to 146181936.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 294846080.0000 - root_mean_squared_error: 17163.7754 - val_loss: 146181936.0000 - val_root_mean_squared_error: 12090.5723
# Epoch 7/100
# 614/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 291551136.0000 - root_mean_squared_error: 17063.6875
# Epoch 7: val_loss improved from 146181936.00000 to 137780064.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 291350176.0000 - root_mean_squared_error: 17057.8359 - val_loss: 137780064.0000 - val_root_mean_squared_error: 11737.9756
# Epoch 8/100
# 604/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 284211008.0000 - root_mean_squared_error: 16829.9316
# Epoch 8: val_loss improved from 137780064.00000 to 133913568.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 283574304.0000 - root_mean_squared_error: 16811.4297 - val_loss: 133913568.0000 - val_root_mean_squared_error: 11572.1025
# Epoch 9/100
# 608/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 273174080.0000 - root_mean_squared_error: 16505.6973
# Epoch 9: val_loss improved from 133913568.00000 to 128566496.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 272871360.0000 - root_mean_squared_error: 16496.8809 - val_loss: 128566496.0000 - val_root_mean_squared_error: 11338.7168
# Epoch 10/100
# 608/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 229249008.0000 - root_mean_squared_error: 15124.0322
# Epoch 10: val_loss improved from 128566496.00000 to 123619856.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 229541920.0000 - root_mean_squared_error: 15133.9170 - val_loss: 123619856.0000 - val_root_mean_squared_error: 11118.4463
# Epoch 11/100
# 612/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 247282816.0000 - root_mean_squared_error: 15712.9434
# Epoch 11: val_loss improved from 123619856.00000 to 118345832.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 247101408.0000 - root_mean_squared_error: 15707.2783 - val_loss: 118345832.0000 - val_root_mean_squared_error: 10878.6865
# Epoch 12/100
# 600/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 234438816.0000 - root_mean_squared_error: 15302.8213
# Epoch 12: val_loss improved from 118345832.00000 to 114657176.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 234263296.0000 - root_mean_squared_error: 15297.3467 - val_loss: 114657176.0000 - val_root_mean_squared_error: 10707.8086
# Epoch 13/100
# 604/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 230777440.0000 - root_mean_squared_error: 15173.7959
# Epoch 13: val_loss improved from 114657176.00000 to 106572976.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 230621552.0000 - root_mean_squared_error: 15169.1123 - val_loss: 106572976.0000 - val_root_mean_squared_error: 10323.4189
# Epoch 14/100
# 603/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 216565136.0000 - root_mean_squared_error: 14709.7998
# Epoch 14: val_loss improved from 106572976.00000 to 105375856.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 216585072.0000 - root_mean_squared_error: 14710.6592 - val_loss: 105375856.0000 - val_root_mean_squared_error: 10265.2744
# Epoch 15/100
# 605/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 208468064.0000 - root_mean_squared_error: 14426.7754
# Epoch 15: val_loss improved from 105375856.00000 to 99381392.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 208679520.0000 - root_mean_squared_error: 14434.3281 - val_loss: 99381392.0000 - val_root_mean_squared_error: 9969.0215
# Epoch 16/100
# 615/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 201606112.0000 - root_mean_squared_error: 14191.8438
# Epoch 16: val_loss improved from 99381392.00000 to 95824960.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 201654656.0000 - root_mean_squared_error: 14193.6104 - val_loss: 95824960.0000 - val_root_mean_squared_error: 9789.0225
# Epoch 17/100
# 607/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 208046592.0000 - root_mean_squared_error: 14415.0781
# Epoch 17: val_loss improved from 95824960.00000 to 90217664.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 207996432.0000 - root_mean_squared_error: 14413.5322 - val_loss: 90217664.0000 - val_root_mean_squared_error: 9498.2979
# Epoch 18/100
# 616/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 200546192.0000 - root_mean_squared_error: 14155.8643
# Epoch 18: val_loss improved from 90217664.00000 to 87196608.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 200529088.0000 - root_mean_squared_error: 14155.3037 - val_loss: 87196608.0000 - val_root_mean_squared_error: 9337.9121
# Epoch 19/100
# 605/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 182835344.0000 - root_mean_squared_error: 13514.4951
# Epoch 19: val_loss improved from 87196608.00000 to 84814416.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 183016016.0000 - root_mean_squared_error: 13521.2969 - val_loss: 84814416.0000 - val_root_mean_squared_error: 9209.4746
# Epoch 20/100
# 607/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 187900736.0000 - root_mean_squared_error: 13696.4736
# Epoch 20: val_loss improved from 84814416.00000 to 80595152.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 187701024.0000 - root_mean_squared_error: 13689.3535 - val_loss: 80595152.0000 - val_root_mean_squared_error: 8977.4805
# Epoch 21/100
# 598/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 181329008.0000 - root_mean_squared_error: 13459.4541
# Epoch 21: val_loss improved from 80595152.00000 to 73550008.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 181395184.0000 - root_mean_squared_error: 13462.1416 - val_loss: 73550008.0000 - val_root_mean_squared_error: 8576.1299
# Epoch 22/100
# 611/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 164545392.0000 - root_mean_squared_error: 12821.7021
# Epoch 22: val_loss improved from 73550008.00000 to 73341248.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 164673040.0000 - root_mean_squared_error: 12826.7139 - val_loss: 73341248.0000 - val_root_mean_squared_error: 8563.9502
# Epoch 23/100
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 162478416.0000 - root_mean_squared_error: 12744.8174
# Epoch 23: val_loss improved from 73341248.00000 to 67367664.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 162481632.0000 - root_mean_squared_error: 12744.9463 - val_loss: 67367664.0000 - val_root_mean_squared_error: 8207.7803
# Epoch 24/100
# 615/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 170197776.0000 - root_mean_squared_error: 13040.8936
# Epoch 24: val_loss improved from 67367664.00000 to 66005584.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 170187248.0000 - root_mean_squared_error: 13040.5391 - val_loss: 66005584.0000 - val_root_mean_squared_error: 8124.3823
# Epoch 25/100
# 601/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 158265472.0000 - root_mean_squared_error: 12574.5947
# Epoch 25: val_loss did not improve from 66005584.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 158157232.0000 - root_mean_squared_error: 12570.4551 - val_loss: 72343040.0000 - val_root_mean_squared_error: 8505.4717
# Epoch 26/100
# 619/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 155827712.0000 - root_mean_squared_error: 12480.9727
# Epoch 26: val_loss improved from 66005584.00000 to 61140216.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 155828272.0000 - root_mean_squared_error: 12481.0020 - val_loss: 61140216.0000 - val_root_mean_squared_error: 7819.2207
# Epoch 27/100
# 602/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 151876720.0000 - root_mean_squared_error: 12316.6543
# Epoch 27: val_loss did not improve from 61140216.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 152046880.0000 - root_mean_squared_error: 12323.7148 - val_loss: 64998808.0000 - val_root_mean_squared_error: 8062.1836
# Epoch 28/100
# 618/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 160251984.0000 - root_mean_squared_error: 12651.5771
# Epoch 28: val_loss improved from 61140216.00000 to 59813808.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 160236880.0000 - root_mean_squared_error: 12651.0146 - val_loss: 59813808.0000 - val_root_mean_squared_error: 7733.9385
# Epoch 29/100
# 601/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 142807936.0000 - root_mean_squared_error: 11942.7539
# Epoch 29: val_loss improved from 59813808.00000 to 55988772.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 143019616.0000 - root_mean_squared_error: 11951.7520 - val_loss: 55988772.0000 - val_root_mean_squared_error: 7482.5645
# Epoch 30/100
# 604/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 156357904.0000 - root_mean_squared_error: 12502.5527
# Epoch 30: val_loss improved from 55988772.00000 to 55745036.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 156265664.0000 - root_mean_squared_error: 12498.8926 - val_loss: 55745036.0000 - val_root_mean_squared_error: 7466.2598
# Epoch 31/100
# 601/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 144395408.0000 - root_mean_squared_error: 12013.2139
# Epoch 31: val_loss improved from 55745036.00000 to 54746500.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 144507184.0000 - root_mean_squared_error: 12017.9414 - val_loss: 54746500.0000 - val_root_mean_squared_error: 7399.0879
# Epoch 32/100
# 601/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 143614240.0000 - root_mean_squared_error: 11982.5859
# Epoch 32: val_loss did not improve from 54746500.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 143759952.0000 - root_mean_squared_error: 11988.6602 - val_loss: 56456832.0000 - val_root_mean_squared_error: 7513.7759
# Epoch 33/100
# 612/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 140619808.0000 - root_mean_squared_error: 11851.6494
# Epoch 33: val_loss did not improve from 54746500.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 140801488.0000 - root_mean_squared_error: 11859.2432 - val_loss: 56593996.0000 - val_root_mean_squared_error: 7522.8984
# Epoch 34/100
# 606/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 143007376.0000 - root_mean_squared_error: 11955.3467
# Epoch 34: val_loss improved from 54746500.00000 to 54148160.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 143055168.0000 - root_mean_squared_error: 11957.4160 - val_loss: 54148160.0000 - val_root_mean_squared_error: 7358.5435
# Epoch 35/100
# 601/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 148802016.0000 - root_mean_squared_error: 12194.0488
# Epoch 35: val_loss did not improve from 54148160.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 148874144.0000 - root_mean_squared_error: 12197.1357 - val_loss: 55028756.0000 - val_root_mean_squared_error: 7418.1367
# Epoch 36/100
# 608/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 142433264.0000 - root_mean_squared_error: 11920.8965
# Epoch 36: val_loss did not improve from 54148160.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 142432864.0000 - root_mean_squared_error: 11921.1660 - val_loss: 56070432.0000 - val_root_mean_squared_error: 7488.0195
# Epoch 37/100
# 600/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 146963376.0000 - root_mean_squared_error: 12121.8506
# Epoch 37: val_loss improved from 54148160.00000 to 53298800.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 146906384.0000 - root_mean_squared_error: 12119.5264 - val_loss: 53298800.0000 - val_root_mean_squared_error: 7300.6025
# Epoch 38/100
# 602/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 146127664.0000 - root_mean_squared_error: 12086.3145
# Epoch 38: val_loss improved from 53298800.00000 to 53082464.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 146248864.0000 - root_mean_squared_error: 12091.3545 - val_loss: 53082464.0000 - val_root_mean_squared_error: 7285.7715
# Epoch 39/100
# 615/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 143026464.0000 - root_mean_squared_error: 11955.0195
# Epoch 39: val_loss did not improve from 53082464.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 143054736.0000 - root_mean_squared_error: 11956.2373 - val_loss: 53874480.0000 - val_root_mean_squared_error: 7339.9238
# Epoch 40/100
# 606/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 143201952.0000 - root_mean_squared_error: 11960.7266
# Epoch 40: val_loss did not improve from 53082464.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 143277872.0000 - root_mean_squared_error: 11964.0254 - val_loss: 55077152.0000 - val_root_mean_squared_error: 7421.3979
# Epoch 41/100
# 606/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 143479504.0000 - root_mean_squared_error: 11975.7539
# Epoch 41: val_loss did not improve from 53082464.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 143576864.0000 - root_mean_squared_error: 11979.8506 - val_loss: 53500752.0000 - val_root_mean_squared_error: 7314.4209
# Epoch 42/100
# 608/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 141793040.0000 - root_mean_squared_error: 11906.3857
# Epoch 42: val_loss improved from 53082464.00000 to 51508436.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 141839696.0000 - root_mean_squared_error: 11908.3643 - val_loss: 51508436.0000 - val_root_mean_squared_error: 7176.9375
# Epoch 43/100
# 613/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 133955704.0000 - root_mean_squared_error: 11571.1611
# Epoch 43: val_loss did not improve from 51508436.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 133965664.0000 - root_mean_squared_error: 11571.6260 - val_loss: 54296784.0000 - val_root_mean_squared_error: 7368.6353
# Epoch 44/100
# 618/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 152007408.0000 - root_mean_squared_error: 12314.1338
# Epoch 44: val_loss did not improve from 51508436.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 151949440.0000 - root_mean_squared_error: 12311.8066 - val_loss: 52193312.0000 - val_root_mean_squared_error: 7224.4937
# Epoch 45/100
# 610/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 131181024.0000 - root_mean_squared_error: 11447.5352
# Epoch 45: val_loss did not improve from 51508436.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 131298568.0000 - root_mean_squared_error: 11452.7080 - val_loss: 52270692.0000 - val_root_mean_squared_error: 7229.8472
# Epoch 46/100
# 601/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 141335184.0000 - root_mean_squared_error: 11886.0059
# Epoch 46: val_loss did not improve from 51508436.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 141243552.0000 - root_mean_squared_error: 11882.2109 - val_loss: 54237400.0000 - val_root_mean_squared_error: 7364.6045
# Epoch 47/100
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 133678016.0000 - root_mean_squared_error: 11560.3447
# Epoch 47: val_loss did not improve from 51508436.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 133682944.0000 - root_mean_squared_error: 11560.5586 - val_loss: 52155444.0000 - val_root_mean_squared_error: 7221.8726
# Epoch 48/100
# 616/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 141012400.0000 - root_mean_squared_error: 11871.0215
# Epoch 48: val_loss improved from 51508436.00000 to 50091060.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 140985312.0000 - root_mean_squared_error: 11869.9053 - val_loss: 50091060.0000 - val_root_mean_squared_error: 7077.5039
# Epoch 49/100
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 142452720.0000 - root_mean_squared_error: 11929.3418
# Epoch 49: val_loss improved from 50091060.00000 to 49584036.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 142444800.0000 - root_mean_squared_error: 11929.0166 - val_loss: 49584036.0000 - val_root_mean_squared_error: 7041.5933
# Epoch 50/100
# 607/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 130716752.0000 - root_mean_squared_error: 11429.8945
# Epoch 50: val_loss did not improve from 49584036.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 130774976.0000 - root_mean_squared_error: 11432.5010 - val_loss: 55816892.0000 - val_root_mean_squared_error: 7471.0703
# Epoch 51/100
# 598/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 139458272.0000 - root_mean_squared_error: 11805.4141
# Epoch 51: val_loss improved from 49584036.00000 to 48050204.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 139425136.0000 - root_mean_squared_error: 11804.1504 - val_loss: 48050204.0000 - val_root_mean_squared_error: 6931.8252
# Epoch 52/100
# 607/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 137504736.0000 - root_mean_squared_error: 11724.3447
# Epoch 52: val_loss did not improve from 48050204.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 137487904.0000 - root_mean_squared_error: 11723.6680 - val_loss: 51766700.0000 - val_root_mean_squared_error: 7194.9077
# Epoch 53/100
# 601/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 141817920.0000 - root_mean_squared_error: 11906.1914
# Epoch 53: val_loss did not improve from 48050204.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 141657072.0000 - root_mean_squared_error: 11899.4600 - val_loss: 49577956.0000 - val_root_mean_squared_error: 7041.1616
# Epoch 54/100
# 611/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 132904360.0000 - root_mean_squared_error: 11527.1748
# Epoch 54: val_loss did not improve from 48050204.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 132898688.0000 - root_mean_squared_error: 11526.9492 - val_loss: 52633268.0000 - val_root_mean_squared_error: 7254.8789
# Epoch 55/100
# 604/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 136895888.0000 - root_mean_squared_error: 11698.0967
# Epoch 55: val_loss did not improve from 48050204.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 136858816.0000 - root_mean_squared_error: 11696.5674 - val_loss: 51779844.0000 - val_root_mean_squared_error: 7195.8213
# Epoch 56/100
# 596/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 134468576.0000 - root_mean_squared_error: 11593.4072
# Epoch 56: val_loss did not improve from 48050204.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 134420480.0000 - root_mean_squared_error: 11591.4355 - val_loss: 49702456.0000 - val_root_mean_squared_error: 7049.9971
# Epoch 57/100
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 136069392.0000 - root_mean_squared_error: 11661.5049
# Epoch 57: val_loss did not improve from 48050204.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 136073632.0000 - root_mean_squared_error: 11661.6914 - val_loss: 51695484.0000 - val_root_mean_squared_error: 7189.9570
# Epoch 58/100
# 605/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 134228416.0000 - root_mean_squared_error: 11583.4277
# Epoch 58: val_loss did not improve from 48050204.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 134190480.0000 - root_mean_squared_error: 11581.8447 - val_loss: 50529528.0000 - val_root_mean_squared_error: 7108.4126
# Epoch 59/100
# 597/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 138987776.0000 - root_mean_squared_error: 11787.6748
# Epoch 59: val_loss did not improve from 48050204.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 138793200.0000 - root_mean_squared_error: 11779.4102 - val_loss: 50708304.0000 - val_root_mean_squared_error: 7120.9761
# Epoch 60/100
# 599/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 131296240.0000 - root_mean_squared_error: 11455.7725
# Epoch 60: val_loss did not improve from 48050204.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 131385984.0000 - root_mean_squared_error: 11459.7627 - val_loss: 52942388.0000 - val_root_mean_squared_error: 7276.1519
# Epoch 61/100
# 613/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 128435936.0000 - root_mean_squared_error: 11331.1934
# Epoch 61: val_loss improved from 48050204.00000 to 47281988.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 128472992.0000 - root_mean_squared_error: 11332.8418 - val_loss: 47281988.0000 - val_root_mean_squared_error: 6876.1899
# Epoch 62/100
# 615/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 133444600.0000 - root_mean_squared_error: 11548.6045
# Epoch 62: val_loss did not improve from 47281988.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 133461848.0000 - root_mean_squared_error: 11549.3799 - val_loss: 49151540.0000 - val_root_mean_squared_error: 7010.8159
# Epoch 63/100
# 609/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 133178552.0000 - root_mean_squared_error: 11537.2363
# Epoch 63: val_loss did not improve from 47281988.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 133186568.0000 - root_mean_squared_error: 11537.6426 - val_loss: 50001420.0000 - val_root_mean_squared_error: 7071.1680
# Epoch 64/100
# 604/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 133657096.0000 - root_mean_squared_error: 11555.5723
# Epoch 64: val_loss did not improve from 47281988.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 133646432.0000 - root_mean_squared_error: 11555.2598 - val_loss: 48101364.0000 - val_root_mean_squared_error: 6935.5146
# Epoch 65/100
# 604/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 136602064.0000 - root_mean_squared_error: 11685.2061
# Epoch 65: val_loss did not improve from 47281988.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 136488304.0000 - root_mean_squared_error: 11680.3691 - val_loss: 48466684.0000 - val_root_mean_squared_error: 6961.8018
# Epoch 66/100
# 608/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 129811208.0000 - root_mean_squared_error: 11390.4463
# Epoch 66: val_loss did not improve from 47281988.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 129838944.0000 - root_mean_squared_error: 11391.7236 - val_loss: 50450068.0000 - val_root_mean_squared_error: 7102.8208
# Epoch 67/100
# 608/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 131664936.0000 - root_mean_squared_error: 11472.5635
# Epoch 67: val_loss improved from 47281988.00000 to 46926952.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 131739808.0000 - root_mean_squared_error: 11475.8457 - val_loss: 46926952.0000 - val_root_mean_squared_error: 6850.3247
# Epoch 68/100
# 614/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 131361128.0000 - root_mean_squared_error: 11459.7080
# Epoch 68: val_loss did not improve from 46926952.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 131359056.0000 - root_mean_squared_error: 11459.6348 - val_loss: 51019596.0000 - val_root_mean_squared_error: 7142.8003
# Epoch 69/100
# 599/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 132253032.0000 - root_mean_squared_error: 11498.5635
# Epoch 69: val_loss did not improve from 46926952.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 132262632.0000 - root_mean_squared_error: 11499.0352 - val_loss: 48300940.0000 - val_root_mean_squared_error: 6949.8877
# Epoch 70/100
# 612/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 135516208.0000 - root_mean_squared_error: 11639.6074
# Epoch 70: val_loss did not improve from 46926952.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 135457424.0000 - root_mean_squared_error: 11637.0859 - val_loss: 48776652.0000 - val_root_mean_squared_error: 6984.0283
# Epoch 71/100
# 608/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 124897160.0000 - root_mean_squared_error: 11172.3379
# Epoch 71: val_loss did not improve from 46926952.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 125005240.0000 - root_mean_squared_error: 11177.1953 - val_loss: 50086704.0000 - val_root_mean_squared_error: 7077.1963
# Epoch 72/100
# 613/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 131889672.0000 - root_mean_squared_error: 11480.6602
# Epoch 72: val_loss did not improve from 46926952.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 131906072.0000 - root_mean_squared_error: 11481.4199 - val_loss: 47146308.0000 - val_root_mean_squared_error: 6866.3169
# Epoch 73/100
# 604/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 126937768.0000 - root_mean_squared_error: 11263.4971
# Epoch 73: val_loss did not improve from 46926952.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 126964944.0000 - root_mean_squared_error: 11264.7871 - val_loss: 48737920.0000 - val_root_mean_squared_error: 6981.2549
# Epoch 74/100
# 607/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 125837120.0000 - root_mean_squared_error: 11214.8115
# Epoch 74: val_loss did not improve from 46926952.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 125928632.0000 - root_mean_squared_error: 11218.9238 - val_loss: 48447176.0000 - val_root_mean_squared_error: 6960.4004
# Epoch 75/100
# 605/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 132032160.0000 - root_mean_squared_error: 11487.4404
# Epoch 75: val_loss did not improve from 46926952.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 131946672.0000 - root_mean_squared_error: 11483.7764 - val_loss: 47615852.0000 - val_root_mean_squared_error: 6900.4238
# Epoch 76/100
# 612/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 129863504.0000 - root_mean_squared_error: 11390.3242
# Epoch 76: val_loss improved from 46926952.00000 to 43989200.00000, saving model to best_model.keras
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 129843904.0000 - root_mean_squared_error: 11389.5410 - val_loss: 43989200.0000 - val_root_mean_squared_error: 6632.4355
# Epoch 77/100
# 607/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 129182296.0000 - root_mean_squared_error: 11364.8008
# Epoch 77: val_loss did not improve from 43989200.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 129173536.0000 - root_mean_squared_error: 11364.4385 - val_loss: 46425848.0000 - val_root_mean_squared_error: 6813.6514
# Epoch 78/100
# 603/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 129189536.0000 - root_mean_squared_error: 11363.3301
# Epoch 78: val_loss did not improve from 43989200.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 129124760.0000 - root_mean_squared_error: 11360.5498 - val_loss: 47883992.0000 - val_root_mean_squared_error: 6919.8257
# Epoch 79/100
# 609/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 129429520.0000 - root_mean_squared_error: 11375.4268
# Epoch 79: val_loss did not improve from 43989200.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 129452560.0000 - root_mean_squared_error: 11376.4619 - val_loss: 49089364.0000 - val_root_mean_squared_error: 7006.3799
# Epoch 80/100
# 611/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 125697760.0000 - root_mean_squared_error: 11203.8867
# Epoch 80: val_loss did not improve from 43989200.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 125705360.0000 - root_mean_squared_error: 11204.3477 - val_loss: 51071956.0000 - val_root_mean_squared_error: 7146.4644
# Epoch 81/100
# 618/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 122546376.0000 - root_mean_squared_error: 11069.0400
# Epoch 81: val_loss did not improve from 43989200.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 122550000.0000 - root_mean_squared_error: 11069.2090 - val_loss: 49798048.0000 - val_root_mean_squared_error: 7056.7734
# Epoch 82/100
# 614/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 127546336.0000 - root_mean_squared_error: 11291.3242
# Epoch 82: val_loss did not improve from 43989200.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 127553888.0000 - root_mean_squared_error: 11291.6836 - val_loss: 48815576.0000 - val_root_mean_squared_error: 6986.8145
# Epoch 83/100
# 610/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 128628176.0000 - root_mean_squared_error: 11340.6006
# Epoch 83: val_loss did not improve from 43989200.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 128627256.0000 - root_mean_squared_error: 11340.5742 - val_loss: 49369520.0000 - val_root_mean_squared_error: 7026.3447
# Epoch 84/100
# 612/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 125721216.0000 - root_mean_squared_error: 11211.0146
# Epoch 84: val_loss did not improve from 43989200.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 125752784.0000 - root_mean_squared_error: 11212.4385 - val_loss: 49958516.0000 - val_root_mean_squared_error: 7068.1338
# Epoch 85/100
# 604/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 135452016.0000 - root_mean_squared_error: 11635.2080
# Epoch 85: val_loss did not improve from 43989200.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 135326176.0000 - root_mean_squared_error: 11629.8408 - val_loss: 46096428.0000 - val_root_mean_squared_error: 6789.4351
# Epoch 86/100
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 126812888.0000 - root_mean_squared_error: 11260.0967
# Epoch 86: val_loss did not improve from 43989200.00000
# 620/620 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 126809224.0000 - root_mean_squared_error: 11259.9346 - val_loss: 47751800.0000 - val_root_mean_squared_error: 6910.2676
# Epoch 86: early stopping
# Restoring model weights from the end of the best epoch: 76.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# ✅ Deep Learning - Validation RMSE : 6632.43
# ✅ Deep Learning - Validation R²   : 0.98
#
# Exemples de salaires DL prédits vs réels :
# Prévu : 90158.38 | Réel : 90000.00
# Prévu : 105989.33 | Réel : 105151.50
# Prévu : 105746.05 | Réel : 100000.00
# Prévu : 137336.55 | Réel : 140000.00
# Prévu : 79903.70 | Réel : 79200.00

# %%
import joblib
import tensorflow as tf
import pandas as pd
import numpy as np

# === Chargement scaler avec joblib ===
scaler = joblib.load('/kaggle/input/test_estimation/tensorflow2/default/1/feature_scaler (1).pkl')

# Chargement modèle Keras
model = tf.keras.models.load_model('/kaggle/input/test_estimation/tensorflow2/default/1/final_deep_learning_model.h5')

# === 2. Liste complète des skills ===
all_skills = {
    '', 'airflow', 'airtable', 'alteryx', 'angular', 'angular.js', 'ansible', 'apl', 'arch',
    'asana', 'asp.net', 'asp.net core', 'asp.netcore', 'assembly', 'atlassian', 'aurora', 'aws',
    'azure', 'bash', 'bigquery', 'bitbucket', 'blazor', 'c', 'c#', 'c++', 'capacitor', 'cassandra',
    'centos', 'chainer', 'chef', 'clickup', 'clojure', 'cobol', 'codecommit', 'cognos', 'colocation',
    'confluence', 'cordova', 'couchbase', 'couchdb', 'crystal', 'css', 'dart', 'databricks', 'datarobot',
    'dax', 'db2', 'debian', 'delphi', 'deno', 'digitalocean', 'dingtalk', 'django', 'dlib', 'docker',
    'dplyr', 'drupal', 'dynamodb', 'elasticsearch', 'electron', 'elixir', 'ember.js', 'erlang',
    'esquisse', 'excel', 'express', 'f#', 'fastapi', 'fastify', 'fedora', 'firebase', 'firestore',
    'flask', 'flow', 'flutter', 'fortran', 'gatsby', 'gcp', 'gdpr', 'ggplot2', 'git', 'github',
    'gitlab', 'go', 'golang', 'google chat', 'graphql', 'groovy', 'gtx', 'hadoop', 'haskell',
    'heroku', 'homebrew', 'html', 'hugging face', 'huggingface', 'ibm cloud', 'ionic', 'java',
    'javascript', 'jenkins', 'jira', 'jquery', 'julia', 'jupyter', 'kafka', 'kali', 'keras',
    'kotlin', 'kubernetes', 'laravel', 'linode', 'linux', 'lisp', 'looker', 'lua', 'macos',
    'mariadb', 'matlab', 'matplotlib', 'mattermost', 'microsoft lists', 'microsoft teams',
    'microstrategy', 'mlpack', 'mlr', 'monday.com', 'mongo', 'mongodb', 'ms access', 'msaccess',
    'mxnet', 'mysql', 'neo4j', 'next.js', 'nltk', 'no-sql', 'node', 'node.js', 'nosql', 'notion',
    'npm', 'nuix', 'numpy', 'nuxt.js', 'objective-c', 'ocaml', 'opencv', 'openstack', 'oracle',
    'outlook', 'ovh', 'pandas', 'pascal', 'perl', 'phoenix', 'php', 'planner', 'play framework',
    'plotly', 'postgresql', 'power bi', 'powerbi', 'powerpoint', 'powershell', 'pulumi', 'puppet',
    'pyspark', 'python', 'pytorch', 'qlik', 'qt', 'r', 'react', 'react.js', 'redhat', 'redis',
    'redshift', 'ringcentral', 'rocketchat', 'rshiny', 'ruby', 'ruby on rails', 'rubyon rails',
    'rust', 'sap', 'sas', 'sass', 'scala', 'scikit-learn', 'seaborn', 'selenium', 'sharepoint',
    'sheets', 'shell', 'shogun', 'slack', 'smartsheet', 'snowflake', 'solidity', 'spark', 'splunk',
    'spreadsheet', 'spring'
}
all_skills = {s.strip().lower() for s in all_skills if s.strip()}

# === 3. Définir les entrées utilisateur ===
job_title_input = "Data Scientist"
skills_input = "python, sql, machine learning"

# === 4. Get the actual feature names the scaler was trained on ===
# These should match exactly what was used during training
scaler_features = scaler.feature_names_in_

# === 5. Create a DataFrame with all expected features initialized to 0 ===
X_input = pd.DataFrame(0, index=[0], columns=scaler_features)

# === 6. Set the job title feature ===
job_title_col = f"jobtitle_{job_title_input}"
if job_title_col in scaler_features:
    X_input[job_title_col] = 1

# === 7. Set the skill features ===
skills_list = [s.strip().lower() for s in skills_input.split(',')]
for skill in skills_list:
    skill_col = f"skill_{skill}"
    if skill_col in scaler_features:
        X_input[skill_col] = 1

# === 8. Standardisation + Prédiction ===
X_input_scaled = scaler.transform(X_input)
predicted_salary = model.predict(X_input_scaled)[0][0]

# === 9. Affichage résultat ===
print("\n=== RÉSULTAT DE LA PRÉDICTION ===")
print(f"💼 Job Title        : {job_title_input}")
print(f"🛠️  Compétences      : {', '.join(skills_list)}")
print(f"💰 Salaire estimé   : {predicted_salary:,.2f} €")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
#
# === RÉSULTAT DE LA PRÉDICTION ===
# 💼 Job Title        : Data Scientist
# 🛠️  Compétences      : python, sql, machine learning
# 💰 Salaire estimé   : 33,908.08 €
